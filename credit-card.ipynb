# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/credit-card-approval-prediction/credit_record.csv
# /kaggle/input/credit-card-approval-prediction/application_record.csv

# %%
df = pd.read_csv('../input/credit-card-approval-prediction/application_record.csv',header = 0)

# %%
df_label= pd.read_csv('../input/credit-card-approval-prediction/credit_record.csv',header = 0)

# %%
df_label
# Out:
#               ID  MONTHS_BALANCE STATUS
# 0        5001711               0      X
# 1        5001711              -1      0
# 2        5001711              -2      0
# 3        5001711              -3      0
# 4        5001712               0      C
# ...          ...             ...    ...
# 1048570  5150487             -25      C
# 1048571  5150487             -26      C
# 1048572  5150487             -27      C
# 1048573  5150487             -28      C
# 1048574  5150487             -29      C
#
# [1048575 rows x 3 columns]

# %%
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0               Working               Higher education
# 1               427500.0               Working               Higher education
# 2               112500.0               Working  Secondary / secondary special
# 3               270000.0  Commercial associate  Secondary / secondary special
# 4               270000.0  Commercial associate  Secondary / secondary special
# ...                  ...                   ...                            ...
# 438552          135000.0             Pensioner  Secondary / secondary special
# 438553          103500.0               Working  Secondary / secondary special
# 438554           54000.0  Commercial associate               Higher education
# 438555           72000.0             Pensioner  Secondary / secondary special
# 438556          121500.0               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage   Rented apartment      -12005          -4542
# 1             Civil marriage   Rented apartment      -12005          -4542
# 2                    Married  House / apartment      -21474          -1134
# 3       Single / not married  House / apartment      -19110          -3051
# 4       Single / not married  House / apartment      -19110          -3051
# ...                      ...                ...         ...            ...
# 438552             Separated  House / apartment      -22717         365243
# 438553  Single / not married  House / apartment      -15939          -3007
# 438554  Single / not married       With parents       -8169           -372
# 438555               Married  House / apartment      -21673         365243
# 438556               Married  House / apartment      -18858          -1201
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0                1                1           0           0             NaN
# 1                1                1           0           0             NaN
# 2                1                0           0           0  Security staff
# 3                1                0           1           1     Sales staff
# 4                1                0           1           1     Sales staff
# ...            ...              ...         ...         ...             ...
# 438552           1                0           0           0             NaN
# 438553           1                0           0           0        Laborers
# 438554           1                1           0           0     Sales staff
# 438555           1                0           0           0             NaN
# 438556           1                0           1           0     Sales staff
#
#         CNT_FAM_MEMBERS
# 0                   2.0
# 1                   2.0
# 2                   2.0
# 3                   1.0
# 4                   1.0
# ...                 ...
# 438552              1.0
# 438553              1.0
# 438554              1.0
# 438555              2.0
# 438556              2.0
#
# [438557 rows x 18 columns]

# %%
df.describe()
# Out:
#                  ID   CNT_CHILDREN  AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count  4.385570e+05  438557.000000      4.385570e+05  438557.000000
# mean   6.022176e+06       0.427390      1.875243e+05  -15997.904649
# std    5.716370e+05       0.724882      1.100869e+05    4185.030007
# min    5.008804e+06       0.000000      2.610000e+04  -25201.000000
# 25%    5.609375e+06       0.000000      1.215000e+05  -19483.000000
# 50%    6.047745e+06       0.000000      1.607805e+05  -15630.000000
# 75%    6.456971e+06       1.000000      2.250000e+05  -12514.000000
# max    7.999952e+06      19.000000      6.750000e+06   -7489.000000
#
#        DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE     FLAG_PHONE  \
# count  438557.000000    438557.0    438557.000000  438557.000000
# mean    60563.675328         1.0         0.206133       0.287771
# std    138767.799647         0.0         0.404527       0.452724
# min    -17531.000000         1.0         0.000000       0.000000
# 25%     -3103.000000         1.0         0.000000       0.000000
# 50%     -1467.000000         1.0         0.000000       0.000000
# 75%      -371.000000         1.0         0.000000       1.000000
# max    365243.000000         1.0         1.000000       1.000000
#
#           FLAG_EMAIL  CNT_FAM_MEMBERS
# count  438557.000000    438557.000000
# mean        0.108207         2.194465
# std         0.310642         0.897207
# min         0.000000         1.000000
# 25%         0.000000         2.000000
# 50%         0.000000         2.000000
# 75%         0.000000         3.000000
# max         1.000000        20.000000

# %%
df.isnull().any()
# Out:
# ID                     False
# CODE_GENDER            False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_BIRTH             False
# DAYS_EMPLOYED          False
# FLAG_MOBIL             False
# FLAG_WORK_PHONE        False
# FLAG_PHONE             False
# FLAG_EMAIL             False
# OCCUPATION_TYPE         True
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df.groupby('OCCUPATION_TYPE')['OCCUPATION_TYPE'].count()
# Out:
# OCCUPATION_TYPE
# Accountants              15985
# Cleaning staff            5845
# Cooking staff             8076
# Core staff               43007
# Drivers                  26090
# HR staff                   774
# High skill tech staff    17289
# IT staff                   604
# Laborers                 78240
# Low-skill Laborers        2140
# Managers                 35487
# Medicine staff           13520
# Private service staff     3456
# Realty agents             1041
# Sales staff              41098
# Secretaries               2044
# Security staff            7993
# Waiters/barmen staff      1665
# Name: OCCUPATION_TYPE, dtype: int64

# %%
df_clean = df.dropna(axis=0)

# %%
df_clean.isnull().any()
# Out:
# ID                     False
# CODE_GENDER            False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_BIRTH             False
# DAYS_EMPLOYED          False
# FLAG_MOBIL             False
# FLAG_WORK_PHONE        False
# FLAG_PHONE             False
# FLAG_EMAIL             False
# OCCUPATION_TYPE        False
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df_clean_drop = df_clean.drop(['CODE_GENDER','DAYS_BIRTH', 'FLAG_EMAIL','FLAG_WORK_PHONE','FLAG_PHONE','FLAG_MOBIL'],axis = 1)

# %%
df_clean_drop.isnull().any()
# Out:
# ID                     False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_EMPLOYED          False
# OCCUPATION_TYPE        False
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df_clean_drop.dtypes
# Out:
# ID                       int64
# FLAG_OWN_CAR            object
# FLAG_OWN_REALTY         object
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE        object
# NAME_EDUCATION_TYPE     object
# NAME_FAMILY_STATUS      object
# NAME_HOUSING_TYPE       object
# DAYS_EMPLOYED            int64
# OCCUPATION_TYPE         object
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
df_clean_drop['FLAG_OWN_CAR'] = pd.factorize(df_clean_drop['FLAG_OWN_CAR'])[0]
df_clean_drop['FLAG_OWN_REALTY'] = pd.factorize(df_clean_drop['FLAG_OWN_REALTY'])[0]
df_clean_drop['NAME_INCOME_TYPE'] = pd.factorize(df_clean_drop['NAME_INCOME_TYPE'])[0]
df_clean_drop['NAME_EDUCATION_TYPE'] = pd.factorize(df_clean_drop['NAME_EDUCATION_TYPE'])[0]
df_clean_drop['NAME_FAMILY_STATUS'] = pd.factorize(df_clean_drop['NAME_FAMILY_STATUS'])[0]
df_clean_drop['NAME_HOUSING_TYPE'] = pd.factorize(df_clean_drop['NAME_HOUSING_TYPE'])[0]
df_clean_drop['OCCUPATION_TYPE'] = pd.factorize(df_clean_drop['OCCUPATION_TYPE'])[0]

# %%
df_clean_drop.dtypes
# Out:
# ID                       int64
# FLAG_OWN_CAR             int64
# FLAG_OWN_REALTY          int64
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE         int64
# NAME_EDUCATION_TYPE      int64
# NAME_FAMILY_STATUS       int64
# NAME_HOUSING_TYPE        int64
# DAYS_EMPLOYED            int64
# OCCUPATION_TYPE          int64
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
X = df_clean_drop.values
X.shape
# Out:
# (304354, 12)

# %%
df_label.groupby('ID')['STATUS'].count()
# Out:
# ID
# 5001711     4
# 5001712    19
# 5001713    22
# 5001714    15
# 5001715    60
#            ..
# 5150482    18
# 5150483    18
# 5150484    13
# 5150485     2
# 5150487    30
# Name: STATUS, Length: 45985, dtype: int64

# %%
df_label
# Out:
#               ID  MONTHS_BALANCE STATUS
# 0        5001711               0      X
# 1        5001711              -1      0
# 2        5001711              -2      0
# 3        5001711              -3      0
# 4        5001712               0      C
# ...          ...             ...    ...
# 1048570  5150487             -25      C
# 1048571  5150487             -26      C
# 1048572  5150487             -27      C
# 1048573  5150487             -28      C
# 1048574  5150487             -29      C
#
# [1048575 rows x 3 columns]

# %%
df_label['STATUS'], labels = pd.factorize(df_label['STATUS'])

# %%
labels
# Out:
# Index(['X', '0', 'C', '1', '2', '3', '4', '5'], dtype='object')

# %%
df_label
# Out:
#               ID  MONTHS_BALANCE  STATUS
# 0        5001711               0       0
# 1        5001711              -1       1
# 2        5001711              -2       1
# 3        5001711              -3       1
# 4        5001712               0       2
# ...          ...             ...     ...
# 1048570  5150487             -25       2
# 1048571  5150487             -26       2
# 1048572  5150487             -27       2
# 1048573  5150487             -28       2
# 1048574  5150487             -29       2
#
# [1048575 rows x 3 columns]

# %%
df_label_clean = df_label[df_label['STATUS'] !=0]

# %%
df_label_clean
# Out:
#               ID  MONTHS_BALANCE  STATUS
# 1        5001711              -1       1
# 2        5001711              -2       1
# 3        5001711              -3       1
# 4        5001712               0       2
# 5        5001712              -1       2
# ...          ...             ...     ...
# 1048570  5150487             -25       2
# 1048571  5150487             -26       2
# 1048572  5150487             -27       2
# 1048573  5150487             -28       2
# 1048574  5150487             -29       2
#
# [839345 rows x 3 columns]

# %%
df_label_clean['STATUS'][df_label['STATUS'] > 2] = 1
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:992: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)

# %%
df_label_clean['STATUS'][df_label['STATUS'] <= 2] = 0
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:992: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)

# %%
df_label_clean.groupby('STATUS')['STATUS'].count()
# Out:
# STATUS
# 0    825151
# 1     14194
# Name: STATUS, dtype: int64

# %%
df_label_group = df_label_clean.groupby('ID').mean()

# %%
df_label_group
# Out:
#          MONTHS_BALANCE    STATUS
# ID
# 5001711       -2.000000  0.000000
# 5001712       -9.000000  0.000000
# 5001717      -10.500000  0.000000
# 5001718      -18.724138  0.068966
# 5001719      -21.000000  0.000000
# ...                 ...       ...
# 5150480      -36.500000  0.000000
# 5150482      -19.500000  0.000000
# 5150484       -6.000000  0.000000
# 5150485       -0.500000  0.000000
# 5150487      -14.500000  0.000000
#
# [41449 rows x 2 columns]

# %% [markdown]
# > 0 คือลุกค้าดี แต่ 1 คือลุกค้าไม่ดีจ่ายหนี้นานกว่า 2 เดือนขึ้นไป

# %%
df_label_group['STATUS'][df_label_group['STATUS'] > 0] = 1
df_label_group['STATUS'][df_label_group['STATUS'] <= 0] = 0

# %%
df_label_group.groupby('STATUS')['STATUS'].count()
# Out:
# STATUS
# 0.0    36099
# 1.0     5350
# Name: STATUS, dtype: int64

# %%
df_label_group
# Out:
#          MONTHS_BALANCE  STATUS
# ID
# 5001711       -2.000000     0.0
# 5001712       -9.000000     0.0
# 5001717      -10.500000     0.0
# 5001718      -18.724138     1.0
# 5001719      -21.000000     0.0
# ...                 ...     ...
# 5150480      -36.500000     0.0
# 5150482      -19.500000     0.0
# 5150484       -6.000000     0.0
# 5150485       -0.500000     0.0
# 5150487      -14.500000     0.0
#
# [41449 rows x 2 columns]

# %%
client_id = df_label_group.index.values
client_label = df_label_group['STATUS'].values

# %%
df.describe()
# Out:
#                  ID   CNT_CHILDREN  AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count  4.385570e+05  438557.000000      4.385570e+05  438557.000000
# mean   6.022176e+06       0.427390      1.875243e+05  -15997.904649
# std    5.716370e+05       0.724882      1.100869e+05    4185.030007
# min    5.008804e+06       0.000000      2.610000e+04  -25201.000000
# 25%    5.609375e+06       0.000000      1.215000e+05  -19483.000000
# 50%    6.047745e+06       0.000000      1.607805e+05  -15630.000000
# 75%    6.456971e+06       1.000000      2.250000e+05  -12514.000000
# max    7.999952e+06      19.000000      6.750000e+06   -7489.000000
#
#        DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE     FLAG_PHONE  \
# count  438557.000000    438557.0    438557.000000  438557.000000
# mean    60563.675328         1.0         0.206133       0.287771
# std    138767.799647         0.0         0.404527       0.452724
# min    -17531.000000         1.0         0.000000       0.000000
# 25%     -3103.000000         1.0         0.000000       0.000000
# 50%     -1467.000000         1.0         0.000000       0.000000
# 75%      -371.000000         1.0         0.000000       1.000000
# max    365243.000000         1.0         1.000000       1.000000
#
#           FLAG_EMAIL  CNT_FAM_MEMBERS
# count  438557.000000    438557.000000
# mean        0.108207         2.194465
# std         0.310642         0.897207
# min         0.000000         1.000000
# 25%         0.000000         2.000000
# 50%         0.000000         2.000000
# 75%         0.000000         3.000000
# max         1.000000        20.000000

# %%
X_client_id = df_clean_drop['ID'].values
df_clean_drop = df_clean_drop.drop(['ID'],axis=1)

# %%
X = df_clean_drop.values
X.shape
# Out:
# (304354, 11)

# %%
real_client_id= [ item for item in X_client_id if item in client_id ]

# %%
len(real_client_id)
# Out:
# 22737

# %%
y = np.array([client_label[np.where(client_id == item)][0]for item in real_client_id])

# %%
X_final = [X[np.where(X_client_id == item), :][0] for item in real_client_id]

# %%
X_final[0].shape
# Out:
# (1, 11)

# %%
np.array(X_final).shape
# Out:
# (22737, 1, 11)

# %%
X_real_final = np.vstack(X_final)

# %%
X_real_final.shape
# Out:
# (22737, 11)

# %%
len(y)
# Out:
# 22737

# %%
sum(y==0)
# Out:
# 19648

# %%
sum(y==1)
# Out:
# 3089

# %%
3089/(19648 + 3089)
# Out:
# 0.1358578528389849

# %% [markdown]
# # Model

# %%
from imblearn.under_sampling import RandomUnderSampler
sm = RandomUnderSampler(random_state=0)
X_res, y_res = sm.fit_resample(X_train, y_train)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=0)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(X_train)
X_train_norm =  scaler.transform(X_train)
X_val_norm = scaler.transform(X_val)
X_test_norm = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

params = {'C': [1, 2, 4, 8, 16, 32]}
clf = GridSearchCV(LogisticRegression(random_state=0, solver='liblinear'),params, cv=10)
clf.fit(X_train_norm, y_train)
print("Best params : " + str(clf.best_params_))
print("10CV accuracy : "+str(clf.best_score_*100))
# Out:
# Best params : {'C': 16}
# 10CV accuracy : 52.884516129032264

# %%
y_predict = clf.predict(X_test_norm)
print("Test accuracy : "+str(sum(y_test == y_predict)/len(y_test)*100))
# Out:
# Test accuracy : 56.26598465473146

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
target_names = ['Good debt', 'Bad debt']
C = confusion_matrix(y_test,y_predict) 
C = C / C.astype(np.float).sum(axis=1)*100
sns.heatmap(C,annot=True, fmt=".2f",cmap="GnBu",xticklabels=target_names, yticklabels=target_names)
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_predict,target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#    Good debt       0.57      0.66      0.61       204
#     Bad debt       0.55      0.45      0.50       187
#
#     accuracy                           0.56       391
#    macro avg       0.56      0.56      0.56       391
# weighted avg       0.56      0.56      0.56       391

# %% [markdown]
# # Deep learning

# %%
import tensorflow as tf
def create_model():
    tf.random.set_seed(0)
    tf.compat.v1.reset_default_graph() # Clear Model
    model = tf.keras.models.Sequential([
      tf.keras.layers.Dense(12, activation='relu', input_shape=(11,)),
      tf.keras.layers.Dense(6, activation='relu'),
      tf.keras.layers.Dense(4, activation='relu'),
      tf.keras.layers.Dense(2, activation='relu'),
      tf.keras.layers.Dense(1, activation='sigmoid')  
    ])
    return model

# %%
model = create_model()
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
train_acc = list()
val_acc = list()
for i in range(0,140):
  history = model.fit(X_train_norm, y_train, epochs= 1, batch_size = 300, validation_data= (X_val_norm, y_val))
  tmp_avg = np.mean(history.history['accuracy'])
  tmp_avg_val = np.mean(history.history['val_accuracy'])
  train_acc.append(tmp_avg)
  val_acc.append(tmp_avg_val)
# Out:
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 295us/sample - loss: 0.6945 - accuracy: 0.4848 - val_loss: 0.6965 - val_accuracy: 0.5304
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 12us/sample - loss: 0.6940 - accuracy: 0.4832 - val_loss: 0.6952 - val_accuracy: 0.5431
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 10us/sample - loss: 0.6935 - accuracy: 0.4904 - val_loss: 0.6949 - val_accuracy: 0.5399
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 12us/sample - loss: 0.6932 - accuracy: 0.4968 - val_loss: 0.6947 - val_accuracy: 0.5304
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 16us/sample - loss: 0.6930 - accuracy: 0.4960 - val_loss: 0.6943 - val_accuracy: 0.5399
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 15us/sample - loss: 0.6927 - accuracy: 0.5064 - val_loss: 0.6941 - val_accuracy: 0.4984
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 11us/sample - loss: 0.6924 - accuracy: 0.5088 - val_loss: 0.6946 - val_accuracy: 0.4249
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 12us/sample - loss: 0.6920 - accuracy: 0.5120 - val_loss: 0.6955 - val_accuracy: 0.4249
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 13us/sample - loss: 0.6915 - accuracy: 0.5120 - val_loss: 0.6964 - val_accuracy: 0.4249
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 12us/sample - loss: 0.6912 - accuracy: 0.5120 - val_loss: 0.6973 - val_accuracy: 0.4249
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 16us/sample - loss: 0.6909 - accuracy: 0.5120 - val_loss: 0.6986 - val_accuracy: 0.4249
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 11us/sample - loss: 0.6907 - accuracy: 0.5120 - val_loss: 0.6997 - val_accuracy: 0.4249
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 17us/sample - loss: 0.6906 - accuracy: 0.5120 - val_loss: 0.7011 - val_accuracy: 0.4249
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 10us/sample - loss: 0.6905 - accuracy: 0.5120 - val_loss: 0.7007 - val_accuracy: 0.4249
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 10us/sample - loss: 0.6903 - accuracy: 0.5120 - val_loss: 0.6988 - val_accuracy: 0.4249
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 12us/sample - loss: 0.6900 - accuracy: 0.5296 - val_loss: 0.6977 - val_accuracy: 0.4569
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 11us/sample - loss: 0.6899 - accuracy: 0.5449 - val_loss: 0.6974 - val_accuracy: 0.4505
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 11us/sample - loss: 0.6897 - accuracy: 0.5457 - val_loss: 0.6980 - val_accuracy: 0.4441
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 11us/sample - loss: 0.6895 - accuracy: 0.5337 - val_loss: 0.6989 - val_accuracy: 0.4473
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 11us/sample - loss: 0.6894 - accuracy: 0.5240 - val_loss: 0.6996 - val_accuracy: 0.4505
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 11us/sample - loss: 0.6894 - accuracy: 0.5184 - val_loss: 0.6994 - val_accuracy: 0.4441
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 12us/sample - loss: 0.
- val_accuracy: 0.5399
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 9us/sample - loss: 0.6765 - accuracy: 0.5970 - val_loss: 0.6962 - val_accuracy: 0.5431
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 9us/sample - loss: 0.6763 - accuracy: 0.5978 - val_loss: 0.6949 - val_accuracy: 0.5463
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 10us/sample - loss: 0.6768 - accuracy: 0.5938 - val_loss: 0.6942 - val_accuracy: 0.5591
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 10us/sample - loss: 0.6765 - accuracy: 0.5970 - val_loss: 0.6962 - val_accuracy: 0.5431
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 9us/sample - loss: 0.6760 - accuracy: 0.6010 - val_loss: 0.6972 - val_accuracy: 0.5399
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 10us/sample - loss: 0.6759 - accuracy: 0.6018 - val_loss: 0.6944 - val_accuracy: 0.5559
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 12us/sample - loss: 0.6762 - accuracy: 0.5954 - val_loss: 0.6932 - val_accuracy: 0.5559
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 10us/sample - loss: 0.6760 - accuracy: 0.5962 - val_loss: 0.6952 - val_accuracy: 0.5559
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 11us/sample - loss: 0.6757 - accuracy: 0.6026 - val_loss: 0.6969 - val_accuracy: 0.5495
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 11us/sample - loss: 0.6754 - accuracy: 0.6010 - val_loss: 0.6960 - val_accuracy: 0.5463
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 10us/sample - loss: 0.6753 - accuracy: 0.5986 - val_loss: 0.6962 - val_accuracy: 0.5463
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 10us/sample - loss: 0.6752 - accuracy: 0.6002 - val_loss: 0.6959 - val_accuracy: 0.5463
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 10us/sample - loss: 0.6751 - accuracy: 0.5970 - val_loss: 0.6966 - val_accuracy: 0.5463
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 10us/sample - loss: 0.6749 - accuracy: 0.5970 - val_loss: 0.6968 - val_accuracy: 0.5463
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 11us/sample - loss: 0.6751 - accuracy: 0.5994 - val_loss: 0.6987 - val_accuracy: 0.5399
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 10us/sample - loss: 0.6750 - accuracy: 0.5970 - val_loss: 0.6966 - val_accuracy: 0.5559
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 9us/sample - loss: 0.6746 - accuracy: 0.6018 - val_loss: 0.6960 - val_accuracy: 0.5559
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 9us/sample - loss: 0.6745 - accuracy: 0.5994 - val_loss: 0.6966 - val_accuracy: 0.5495
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 9us/sample - loss: 0.6745 - accuracy: 0.6002 - val_loss: 0.6949 - val_accuracy: 0.5495
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 10us/sample - loss: 0.6746 - accuracy: 0.5986 - val_loss: 0.6937 - val_accuracy: 0.5623
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 10us/sample - loss: 0.6745 - accuracy: 0.5986 - val_loss: 0.6947 - val_accuracy: 0.5527
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 10us/sample - loss: 0.6739 - accuracy: 0.6002 - val_loss: 0.6962 - val_accuracy: 0.5495
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 10us/sample - loss: 0.6740 - accuracy: 0.5938 - val_loss: 0.6966 - val_accuracy: 0.5463
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 11us/sample - loss: 0.6740 - accuracy: 0.5994 - val_loss: 0.6946 - val_accuracy: 0.5463
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 11us/sample - loss: 0.6740 - accuracy: 0.5994 - val_loss: 0.6951 - val_accuracy: 0.5527
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 10us/sample - loss: 0.6737 - accuracy: 0.5994 - val_loss: 0.6972 - val_accuracy: 0.5495
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 11us/sample - loss: 0.6736 - accuracy: 0.6042 - val_loss: 0.6963 - val_accuracy: 0.5495
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 11us/sample - loss: 0.6735 - accuracy: 0.6002 - val_loss: 0.6949 - val_accuracy: 0.5527
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 11us/sample - loss: 0.6733 - accuracy: 0.6034 - val_loss: 0.6940 - val_accuracy: 0.5527
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 10us/sample - loss: 0.6734 - accuracy: 0.5929 - val_loss: 0.6944 - val_accuracy: 0.5495
# Train on 1248 samples, validate on 313 samples
# 1248/1248 [==============================] - 0s 13us/sample - loss: 0.6732 - accuracy: 0.5921 - val_loss: 0.6948 - val_accuracy: 0.5591

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.figure(num=None, figsize=(16, 8), dpi=90, facecolor='w', edgecolor='k')
plt.plot()
plt.plot(train_acc)
plt.plot(val_acc)
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
y_predict = np.round(model.predict(X_test_norm))
y_predict = [i[0] for i in y_predict.tolist()]
sum(y_predict == y_test)/len(y_test)
# Out:
# 0.5498721227621484

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
target_names = ['Good debt', 'Bad debt']
C = confusion_matrix(y_test,y_predict) 
C = C / C.astype(np.float).sum(axis=1)*100
sns.heatmap(C, annot=True, fmt=".2f",cmap="GnBu",xticklabels=target_names, yticklabels=target_names)
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_predict,target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#    Good debt       0.57      0.56      0.56       204
#     Bad debt       0.53      0.54      0.53       187
#
#     accuracy                           0.55       391
#    macro avg       0.55      0.55      0.55       391
# weighted avg       0.55      0.55      0.55       391
